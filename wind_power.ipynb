# %% [markdown]
# Using measurement csv File

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
# Importing the dataset
measurement_dataset = pd.read_csv('measurement.csv')

# %%
# separating the data & label
X = measurement_dataset.drop(columns = ['ptime','time','power'],axis=1)
Y = measurement_dataset.drop(columns = ['ptime','time','windspeed'],axis=1)

# %%
X
# Out:
#       windspeed
# 0          7.47
# 1          7.62
# 2          8.35
# 3          8.13
# 4          7.73
# ...         ...
# 1225       9.64
# 1226       9.28
# 1227       7.53
# 1228       6.47
# 1229       5.94
#
# [1230 rows x 1 columns]

# %%
Y
# Out:
#       power
# 0      0.32
# 1      0.22
# 2      0.27
# 3      0.12
# 4      0.25
# ...     ...
# 1225   0.55
# 1226   0.94
# 1227   0.35
# 1228   0.09
# 1229   0.13
#
# [1230 rows x 1 columns]

# %%
#Splitting the data into training data & Testing data

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
X_train.shape
# Out:
# (820, 1)

# %%
y_train.shape
# Out:
# (820,)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.25993892],
#        [ 0.39703313],
#        [ 0.05756176],
#        [ 0.17744501],
#        [ 0.27180855],
#        [ 0.13234042],
#        [ 0.28130426],
#        [ 0.3406524 ],
#        [ 0.28486514],
#        [ 0.48664883],
#        [ 0.257565  ],
#        [ 0.13471434],
#        [ 0.14005568],
#        [ 0.10266635],
#        [ 0.2480693 ],
#        [ 0.25519107],
#        [-0.1323523 ],
#        [-0.12404356],
#        [ 0.07121183],
#        [ 0.49495757],
#        [ 0.14658397],
#        [ 0.01483109],
#        [-0.14006756],
#        [ 0.19702989],
#        [ 0.47359224],
#        [ 0.22492352],
#        [ 0.18100589],
#        [-0.0747846 ],
#        [ 0.36498514],
#        [ 0.53294038],
#        [ 0.12521864],
#        [-0.10861304],
#        [ 0.06527702],
#        [ 0.31750662],
#        [ 0.19287552],
#        [-0.11336089],
#        [ 0.26824766],
#        [ 0.34480677],
#        [-0.14481541],
#        [ 0.25934544],
#        [ 0.09791849],
# ...

# %%
score = regressor.score(X_test, y_test) 
print(score*100)
# Out:
# 68.90874687075996

# %%
# Visualising the Training set results
plt.scatter(X_train, y_train, color = 'black')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('windspeed vs power (Training set)')
plt.xlabel('windspeed')
plt.ylabel('power')
plt.show()

# %%
# Visualising the Test set results
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('windspeed vs power (Test set)')
plt.xlabel('windspeed')
plt.ylabel('power')
plt.show()

# %%
# Calculating the MSE and MAE with sklearn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error or L1 Loss:",mae)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error or L2 Loss:",mse)
# Out:
# Mean Absolute Error or L1 Loss: 0.08367588848312628
# Mean Squared Error or L2 Loss: 0.012031737155693015

# %% [markdown]
# Using forecast csv File

# %%
# Importing the dataset
forecast_dataset = pd.read_csv('forecast.csv')

# %%
# separating the data & label
X = forecast_dataset.drop(columns = ['ptime','time','power'],axis=1)
Y = forecast_dataset.drop(columns = ['ptime','time','windspeed'],axis=1)

# %%
X
# Out:
#      windspeed
# 0         7.29
# 1         7.07
# 2         7.27
# 3         7.46
# 4         6.89
# ..         ...
# 265       5.72
# 266       5.31
# 267       5.25
# 268       5.22
# 269       5.48
#
# [270 rows x 1 columns]

# %%
Y
# Out:
#      power
# 0     0.14
# 1     0.17
# 2     0.20
# 3     0.15
# 4     0.26
# ..     ...
# 265   0.52
# 266   0.00
# 267   0.09
# 268   0.14
# 269   0.75
#
# [270 rows x 1 columns]

# %%
#Splitting the data into training data & Testing data

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
X_train.shape
# Out:
# (180, 1)

# %%
y_train.shape
# Out:
# (180, 1)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.29793761],
#        [ 0.03597744],
#        [ 0.10378572],
#        [ 0.11827466],
#        [-0.01038719],
#        [ 0.09335367],
#        [ 0.05742108],
#        [ 0.09393323],
#        [ 0.03134098],
#        [ 0.20752658],
#        [-0.04342199],
#        [ 0.10204704],
#        [-0.15179931],
#        [ 0.27823264],
#        [ 0.16927576],
#        [-0.00343249],
#        [ 0.43297459],
#        [ 0.07133047],
#        [ 0.26664148],
#        [ 0.12986582],
#        [ 0.06785313],
#        [ 0.14899123],
#        [ 0.07596694],
#        [ 0.21390171],
#        [-0.05907005],
#        [ 0.33618843],
#        [ 0.12580892],
#        [ 0.03134098],
#        [ 0.11943378],
#        [ 0.27591441],
#        [ 0.22085641],
#        [ 0.14145698],
#        [ 0.00120397],
#        [ 0.11421776],
#        [ 0.08929677],
#        [ 0.08118296],
#        [ 0.47991878],
#        [-0.03588773],
#        [ 0.10494483],
#        [ 0.07191003],
#        [-0.00343249],
# ...

# %%
score = regressor.score(X_test, y_test) 
print(score*100)
# Out:
# 66.19008237155701

# %%
# Visualising the Training set results
plt.scatter(X_train, y_train, color = 'black')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('windspeed vs power (Training set)')
plt.xlabel('windspeed')
plt.ylabel('power')
plt.show()

# %%
# Visualising the Test set results
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('windspeed vs power (Test set)')
plt.xlabel('windspeed')
plt.ylabel('power')
plt.show()

# %%
# Calculating the MSE and MAE with sklearn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error or L1 Loss:",mae)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error or L2 Loss:",mse)
# Out:
# Mean Absolute Error or L1 Loss: 0.07810856482559128
# Mean Squared Error or L2 Loss: 0.01018172729782456
